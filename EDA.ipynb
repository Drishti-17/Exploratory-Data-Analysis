# %% [markdown]
# <a href="https://colab.research.google.com/github/Drishti-17/Exploratory-Data-Analysis/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **EXPLORATORY DATA ANALYSIS IN PYTHON**

# %% [markdown]
# **What is Exploratory Data Analysis ?**
#
#  Exploratory Data Analysis (EDA) is the process of examining and summarizing a dataset to understand its characteristics, identify patterns, and make informed decisions. It involves calculating summary statistics, visualizing data through plots and charts, identifying missing or inconsistent data, and exploring relationships between variables. EDA provides insights that guide further analysis and decision-making.

# %% [markdown]
# **How to perform Exploratory Data Analysis ?**
#
# Performing EDA involves the following concise steps:
#
# 1. Understand the Data: Get familiar with the dataset's structure, variables, and potential missing values or inconsistencies.
#
# 2. Clean the Data: Handle missing values and erroneous data appropriately.
#
# 3. Calculate Summary Statistics: Compute basic statistics like mean, median, and standard deviation for numeric variables, and frequency counts for categorical variables.
#
# 4. Visualize the Data: Create plots such as histograms, box plots, and scatter plots to visualize the data distribution, outliers, and relationships between variables.
#
# 5. Analyze Relationships: Identify correlations between numeric variables and visualize them using correlation matrices or scatter plots.
#
# 6. Identify Outliers and Anomalies: Spot unusual observations that deviate significantly from the norm.
#
# 7. Handle Categorical Variables: Analyze categorical variables using bar plots or pie charts to understand category distributions.
#
# 8. Iterate and Explore: Continuously explore the data, generate hypotheses, and delve deeper into specific aspects for further analysis.

# %% [markdown]
# **What data are we exploring today ?**
#
#
#
# We have a very beautiful data-set of Google Play store Apps which contains more of 10, 000 rows and more than 10 columns which contains features of the Apps such as Ratings, Installs, App name and many more.

# %% [markdown]
# **Task** : Find best features to help predict installation of App

# %% [markdown]
# ## 1. Importing required libraries for EDA

# %%
import pandas as pd
import numpy as np
import seaborn as sns                      
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Loading the data into the data frame.

# %% [markdown]
# Loading the data into the pandas data frame is certainly one of the most important steps in EDA, as we can see that the value from the data set is comma-separated. So all we have to do is to just read the CSV into a data frame and pandas data frame does the job for us.

# %%
df = pd.read_csv("/content/Google-Playstore.csv") 
df.head()
# Out:
#                                             App Name  \
# 0                                            Gakondo
# 1                                Ampere Battery Info
# 2                                             Vibook
# 3  Smart City Trichy Public Service Vehicles 17UC...
# 4                                            GROW.me
#
#                        App Id       Category  Rating  Rating Count Installs  \
# 0         com.ishakwe.gakondo      Adventure     0.0           0.0      10+
# 1  com.webserveis.batteryinfo          Tools     4.4          64.0   5,000+
# 2        com.doantiepvien.crm   Productivity     0.0           0.0      50+
# 3     cst.stJoseph.ug17ucs548  Communication     5.0           5.0      10+
# 4        com.horodyski.grower          Tools     0.0           0.0     100+
#
#    Minimum Installs  Maximum Installs  Free  Price  ...  \
# 0              10.0              15.0  True    0.0  ...
# 1            5000.0            7662.0  True    0.0  ...
# 2              50.0              58.0  True    0.0  ...
# 3              10.0              19.0  True    0.0  ...
# 4             100.0             478.0  True    0.0  ...
#
#                   Developer Website              Developer Email  \
# 0       https://beniyizibyose.tk/#/       jean21101999@gmail.com
# 1   https://webserveis.netlify.app/         webserveis@gmail.com
# 2                               NaN          vnacrewit@gmail.com
# 3  http://www.climatesmarttech.com/  climatesmarttech2@gmail.com
# 4       http://www.horodyski.com.pl    rmilekhorodyski@gmail.com
#
#        Released  Last Updated Content Rating  \
# 0  Feb 26, 2020  Feb 26, 2020       Everyone
# 1  May 21, 2020  May 06, 2021       Everyone
# 2   Aug 9, 2019  Aug 19, 2019       Everyone
# 3  Sep 10, 2018  Oct 13, 2018       Everyone
# 4  Feb 21, 2020  Nov 12, 2018       Everyone
#
#                                       Privacy Policy Ad Supported  \
# 0                 https://beniyizibyose.tk/projects/        False
# 1  https://dev4phones.wordpress.com/licencia-de-uso/         True
# 2  https://www.vietnamairlines.com/vn/en/terms-an...        False
# 3                                                NaN         True
# 4                        http://www.horodyski.com.pl        False
#
#   In App Purchases Editors Choice         Scraped Time
# 0            False          False  2021-06-15 20:19:35
# 1            False          False  2021-06-15 20:19:35
# 2            False          False  2021-06-15 20:19:35
# 3            False          False  2021-06-15 20:19:35
# 4            False          False  2021-06-15 20:19:35
#
# [5 rows x 24 columns]

# %%
df.tail(15)
# Out:
#                                        App Name  \
# 28653                 Tips Cara Memutihkan Gigi
# 28654            Penguin Collection Tanah Abang
# 28655  Rain Alarm Pro - All features (one-time)
# 28656            Thenali Raman Stories in Tamil
# 28657                               زيارة ودعاء
# 28658                 Dixie Chicks Songs Lyrics
# 28659                     Headlines Hair Studio
# 28660                           PREKSHA CLASSES
# 28661                                 KING SIZE
# 28662                                BusBahnBim
# 28663                            BisTrack Stock
# 28664                Frank Gietzel Ergotherapie
# 28665                              MMA Forum 18
# 28666                           Strategic Leave
# 28667                                     WAPRO
#
#                                                App Id           Category  \
# 28653                com.TipsCaraMemutihkanGigi.atten  Books & Reference
# 28654             com.gcart.android.penguincollection           Business
# 28655                        de.mdiener.rain.usa.plus            Weather
# 28656             com.whiture.apps.tamil.thenaliraman  Books & Reference
# 28657     appinventor.ai_saeed_alttaee811.ZyaraandDua  Books & Reference
# 28658  com.Rifkianshar.DixieChickssnglyrcsya.singsong      Entertainment
# 28659                 com.phorest.headlineshairstudio          Lifestyle
# 28660                                  co.alicia.prec          Education
# 28661                  com.apps.twelve.floor.kingsize       Food & Drink
# 28662                            de.hafas.android.stv  Maps & Navigation
# 28663                           epicor.bistrack.stock           Business
# 28664                              net.ays.PROD501022            Medical
# 28665                       com.kreator.mmaturkey2018           Business
# 28666               com.seasonworkstation.longholiday     Travel & Local
# 28667                                     com.wacore_                NaN
#
#        Rating  Rating Count  Installs  Minimum Installs  Maximum Installs  \
# 28653     0.0           0.0      500+             500.0             507.0
# 28654     4.3           9.0      100+             100.0             373.0
# 28655     4.5        4380.0   50,000+           50000.0           77874.0
# 28656     4.5        1046.0  100,000+          100000.0          131561.0
# 28657     5.0          10.0       10+              10.0              19.0
# 28658     0.0           0.0      100+             100.0             470.0
# 28659     0.0           0.0       10+              10.0              15.0
# 28660     0.0           0.0        1+               1.0               4.0
# 28661     0.0           0.0      100+             100.0             135.0
# 28662     4.6        2589.0  100,000+          100000.0          177994.0
# 28663     0.0           0.0      500+             500.0             815.0
# 28664     0.0           0.0       10+              10.0              23.0
# 28665     0.0           0.0       10+              10.0              19.0
# 28666     0.0           0.0      100+             100.0             142.0
# 28667     NaN           NaN       NaN               NaN               NaN
#
#         Free  Price  ...                                  Developer Website  \
# 28653   True   0.00  ...                                                NaN
# 28654   True   0.00  ...                                                NaN
# 28655  False  10.99  ...                          http://app.rain-alarm.com
# 28656   True   0.00  ...                             http://www.whiture.com
# 28657   True   0.00  ...  https://sites.google.com/view/saeedmax/home?re...
# 28658   True   0.00  ...                                                NaN
# 28659   True   0.00  ...                                                NaN
# 28660   True   0.00  ...                                                NaN
# 28661   True   0.00  ...                            http://floor12apps.com/
# 28662   True   0.00  ...                   http://www.verbundlinie.at/mobil
# 28663   True   0.00  ...  http://www.epicor.com/Products/Pages/BisTrack....
# 28664   True   0.00  ...                  http://www.heise-regioconcept.de/
# 28665   True   0.00  ...                            https://kreator.com.tr/
# 28666   True   0.00  ...                                                NaN
# 28667    NaN    NaN  ...                                                NaN
#
#                       Developer Email      Released  Last Updated  \
# 28653         ummikulsum876@gmail.com   Sep 7, 2015  Sep 07, 2015
# 28654       fifinataliacc15@gmail.com  Sep 10, 2017  Sep 10, 2017
# 28655          android@rain-alarm.com   Feb 3, 2010  Jun 07, 2021
# 28656  sudhakar.kanakaraj@outlook.com  Jul 20, 2013  Mar 22, 2021
# 28657      saeed.alttaee811@gmail.com  Apr 14, 2020  Apr 15, 2020
# 28658          themesongrtv@gmail.com   Mar 3, 2020  Jul 26, 2020
# 28659              deploy@phorest.com   Aug 9, 2017  Sep 07, 2019
# 28660            support@classplus.co  Mar 17, 2020  Apr 15, 2020
# 28661     floor.twelve.apps@gmail.com  Jun 26, 2018  Oct 01, 2018
# 28662        feedback@verbundlinie.at  Jan 17, 2017  May 17, 2021
# 28663      BisTrackSupport@epicor.com  Oct 18, 2019  Apr 23, 2021
# 28664                    fg101@web.de  Dec 22, 2015  Apr 12, 2018
# 28665          tech@kreatoronline.com  Oct 19, 2018  Oct 19, 2018
# 28666    season.workstation@gmail.com   Jan 4, 2017  Jan 12, 2017
# 28667                             NaN           NaN           NaN
#
#       Content Rating                                     Privacy Policy  \
# 28653       Everyone  https://attentsapps.blogspot.com/2021/02/priva...
# 28654       Everyone                  http://gentacart.net/privacy.html
# 28655       Everyone  http://www.rain-alarm.com/android_pro_privacy....
# 28656       Everyone  http://www.whiture.com/p/privacy-policy-sudhak...
# 28657       Everyone  https://sites.google.com/view/saeedmax/home?re...
# 28658           Teen                                                NaN
# 28659       Everyone                   https://zanadoo.me/pages/privacy
# 28660       Everyone              https://classplusapp.com/privacy.html
# 28661       Everyone        https://floor12apps.com/privacy_policy.html
# 28662       Everyone   http://www.verbundlinie.at/datenschutzerklaerung
# 28663       Everyone         http://www.epicor.com/company/privacy.aspx
# 28664       Everyone  http://frank-gietzel-ergotherapie.heise-apps.d...
# 28665       Everyone                            https://kreator.com.tr/
# 28666       Everyone  https://sites.google.com/site/seasonworkstatio...
# 28667            NaN                                                NaN
#
#       Ad Supported In App Purchases Editors Choice         Scraped Time
# 28653         True            False          False  2021-06-15 20:47:54
# 28654        False            False          False  2021-06-15 20:47:54
# 28655        False            False          False  2021-06-15 20:47:54
# 28656         True             True          False  2021-06-15 20:47:54
# 28657        False            False          False  2021-06-15 20:47:55
# 28658         True            False          False  2021-06-15 20:47:55
# 28659        False            False          False  2021-06-15 20:47:55
# 28660        False            False          False  2021-06-15 20:47:55
# 28661        False            False          False  2021-06-15 20:47:55
# 28662        False            False          False  2021-06-15 20:47:55
# 28663        False            False          False  2021-06-15 20:47:55
# 28664        False            False          False  2021-06-15 20:47:55
# 28665        False            False          False  2021-06-15 20:47:55
# 28666         True            False          False  2021-06-15 20:47:55
# 28667          NaN              NaN            NaN                  NaN
#
# [15 rows x 24 columns]

# %% [markdown]
# ## 3. Checking the types of data

# %%
df.dtypes
# Out:
# App Name              object
# App Id                object
# Category              object
# Rating               float64
# Rating Count         float64
# Installs              object
# Minimum Installs     float64
# Maximum Installs     float64
# Free                  object
# Price                float64
# Currency              object
# Size                  object
# Minimum Android       object
# Developer Id          object
# Developer Website     object
# Developer Email       object
# Released              object
# Last Updated          object
# Content Rating        object
# Privacy Policy        object
# Ad Supported          object
# In App Purchases      object
# Editors Choice        object
# Scraped Time          object
# dtype: object

# %% [markdown]
# ## 4. Dropping irrelevant columns

# %%
pd.unique(df['Scraped Time'])
# Out:
# array(['2021-06-15 20:19:35', '2021-06-15 20:19:36',
#        '2021-06-15 20:19:37', ..., '2021-06-15 20:47:54',
#        '2021-06-15 20:47:55', nan], dtype=object)

# %%
df = df.drop(['Scraped Time'], axis=1)
df.head(5)
# Out:
#                                             App Name  \
# 0                                            Gakondo
# 1                                Ampere Battery Info
# 2                                             Vibook
# 3  Smart City Trichy Public Service Vehicles 17UC...
# 4                                            GROW.me
#
#                        App Id       Category  Rating  Rating Count Installs  \
# 0         com.ishakwe.gakondo      Adventure     0.0           0.0      10+
# 1  com.webserveis.batteryinfo          Tools     4.4          64.0   5,000+
# 2        com.doantiepvien.crm   Productivity     0.0           0.0      50+
# 3     cst.stJoseph.ug17ucs548  Communication     5.0           5.0      10+
# 4        com.horodyski.grower          Tools     0.0           0.0     100+
#
#    Minimum Installs  Maximum Installs  Free  Price  ...  \
# 0              10.0              15.0  True    0.0  ...
# 1            5000.0            7662.0  True    0.0  ...
# 2              50.0              58.0  True    0.0  ...
# 3              10.0              19.0  True    0.0  ...
# 4             100.0             478.0  True    0.0  ...
#
#                         Developer Id                 Developer Website  \
# 0  Jean Confident Irénée NIYIZIBYOSE       https://beniyizibyose.tk/#/
# 1                         Webserveis   https://webserveis.netlify.app/
# 2                         Cabin Crew                               NaN
# 3                Climate Smart Tech2  http://www.climatesmarttech.com/
# 4              Rafal Milek-Horodyski       http://www.horodyski.com.pl
#
#                Developer Email      Released  Last Updated Content Rating  \
# 0       jean21101999@gmail.com  Feb 26, 2020  Feb 26, 2020       Everyone
# 1         webserveis@gmail.com  May 21, 2020  May 06, 2021       Everyone
# 2          vnacrewit@gmail.com   Aug 9, 2019  Aug 19, 2019       Everyone
# 3  climatesmarttech2@gmail.com  Sep 10, 2018  Oct 13, 2018       Everyone
# 4    rmilekhorodyski@gmail.com  Feb 21, 2020  Nov 12, 2018       Everyone
#
#                                       Privacy Policy Ad Supported  \
# 0                 https://beniyizibyose.tk/projects/        False
# 1  https://dev4phones.wordpress.com/licencia-de-uso/         True
# 2  https://www.vietnamairlines.com/vn/en/terms-an...        False
# 3                                                NaN         True
# 4                        http://www.horodyski.com.pl        False
#
#   In App Purchases Editors Choice
# 0            False          False
# 1            False          False
# 2            False          False
# 3            False          False
# 4            False          False
#
# [5 rows x 23 columns]

# %% [markdown]
# ## 5. Renaming Columns

# %%
df = df.rename(columns={"App Name": "Name", "App Id": "ID" })
df.head(5)
# Out:
#                                                 Name  \
# 0                                            Gakondo
# 1                                Ampere Battery Info
# 2                                             Vibook
# 3  Smart City Trichy Public Service Vehicles 17UC...
# 4                                            GROW.me
#
#                            ID       Category  Rating  Rating Count Installs  \
# 0         com.ishakwe.gakondo      Adventure     0.0           0.0      10+
# 1  com.webserveis.batteryinfo          Tools     4.4          64.0   5,000+
# 2        com.doantiepvien.crm   Productivity     0.0           0.0      50+
# 3     cst.stJoseph.ug17ucs548  Communication     5.0           5.0      10+
# 4        com.horodyski.grower          Tools     0.0           0.0     100+
#
#    Minimum Installs  Maximum Installs  Free  Price  ...  \
# 0              10.0              15.0  True    0.0  ...
# 1            5000.0            7662.0  True    0.0  ...
# 2              50.0              58.0  True    0.0  ...
# 3              10.0              19.0  True    0.0  ...
# 4             100.0             478.0  True    0.0  ...
#
#                         Developer Id                 Developer Website  \
# 0  Jean Confident Irénée NIYIZIBYOSE       https://beniyizibyose.tk/#/
# 1                         Webserveis   https://webserveis.netlify.app/
# 2                         Cabin Crew                               NaN
# 3                Climate Smart Tech2  http://www.climatesmarttech.com/
# 4              Rafal Milek-Horodyski       http://www.horodyski.com.pl
#
#                Developer Email      Released  Last Updated Content Rating  \
# 0       jean21101999@gmail.com  Feb 26, 2020  Feb 26, 2020       Everyone
# 1         webserveis@gmail.com  May 21, 2020  May 06, 2021       Everyone
# 2          vnacrewit@gmail.com   Aug 9, 2019  Aug 19, 2019       Everyone
# 3  climatesmarttech2@gmail.com  Sep 10, 2018  Oct 13, 2018       Everyone
# 4    rmilekhorodyski@gmail.com  Feb 21, 2020  Nov 12, 2018       Everyone
#
#                                       Privacy Policy Ad Supported  \
# 0                 https://beniyizibyose.tk/projects/        False
# 1  https://dev4phones.wordpress.com/licencia-de-uso/         True
# 2  https://www.vietnamairlines.com/vn/en/terms-an...        False
# 3                                                NaN         True
# 4                        http://www.horodyski.com.pl        False
#
#   In App Purchases Editors Choice
# 0            False          False
# 1            False          False
# 2            False          False
# 3            False          False
# 4            False          False
#
# [5 rows x 23 columns]

# %% [markdown]
# ## 6. Dropping the duplicate rows

# %%
df.shape
# Out:
# (28668, 23)

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (0, 23)

# %%
df.count()      # Used to count the number of rows
# Out:
# Name                 28668
# ID                   28668
# Category             28667
# Rating               28401
# Rating Count         28401
# Installs             28666
# Minimum Installs     28666
# Maximum Installs     28667
# Free                 28667
# Price                28667
# Currency             28666
# Size                 28667
# Minimum Android      28581
# Developer Id         28667
# Developer Website    19207
# Developer Email      28667
# Released             27845
# Last Updated         28667
# Content Rating       28667
# Privacy Policy       23472
# Ad Supported         28667
# In App Purchases     28667
# Editors Choice       28667
# dtype: int64

# %%
df = df.drop_duplicates()
df.head()
# Out:
#                                                 Name  \
# 0                                            Gakondo
# 1                                Ampere Battery Info
# 2                                             Vibook
# 3  Smart City Trichy Public Service Vehicles 17UC...
# 4                                            GROW.me
#
#                            ID       Category  Rating  Rating Count Installs  \
# 0         com.ishakwe.gakondo      Adventure     0.0           0.0      10+
# 1  com.webserveis.batteryinfo          Tools     4.4          64.0   5,000+
# 2        com.doantiepvien.crm   Productivity     0.0           0.0      50+
# 3     cst.stJoseph.ug17ucs548  Communication     5.0           5.0      10+
# 4        com.horodyski.grower          Tools     0.0           0.0     100+
#
#    Minimum Installs  Maximum Installs  Free  Price  ...  \
# 0              10.0              15.0  True    0.0  ...
# 1            5000.0            7662.0  True    0.0  ...
# 2              50.0              58.0  True    0.0  ...
# 3              10.0              19.0  True    0.0  ...
# 4             100.0             478.0  True    0.0  ...
#
#                         Developer Id                 Developer Website  \
# 0  Jean Confident Irénée NIYIZIBYOSE       https://beniyizibyose.tk/#/
# 1                         Webserveis   https://webserveis.netlify.app/
# 2                         Cabin Crew                               NaN
# 3                Climate Smart Tech2  http://www.climatesmarttech.com/
# 4              Rafal Milek-Horodyski       http://www.horodyski.com.pl
#
#                Developer Email      Released  Last Updated Content Rating  \
# 0       jean21101999@gmail.com  Feb 26, 2020  Feb 26, 2020       Everyone
# 1         webserveis@gmail.com  May 21, 2020  May 06, 2021       Everyone
# 2          vnacrewit@gmail.com   Aug 9, 2019  Aug 19, 2019       Everyone
# 3  climatesmarttech2@gmail.com  Sep 10, 2018  Oct 13, 2018       Everyone
# 4    rmilekhorodyski@gmail.com  Feb 21, 2020  Nov 12, 2018       Everyone
#
#                                       Privacy Policy Ad Supported  \
# 0                 https://beniyizibyose.tk/projects/        False
# 1  https://dev4phones.wordpress.com/licencia-de-uso/         True
# 2  https://www.vietnamairlines.com/vn/en/terms-an...        False
# 3                                                NaN         True
# 4                        http://www.horodyski.com.pl        False
#
#   In App Purchases Editors Choice
# 0            False          False
# 1            False          False
# 2            False          False
# 3            False          False
# 4            False          False
#
# [5 rows x 23 columns]

# %%
df.count()
# Out:
# Name                 28668
# ID                   28668
# Category             28667
# Rating               28401
# Rating Count         28401
# Installs             28666
# Minimum Installs     28666
# Maximum Installs     28667
# Free                 28667
# Price                28667
# Currency             28666
# Size                 28667
# Minimum Android      28581
# Developer Id         28667
# Developer Website    19207
# Developer Email      28667
# Released             27845
# Last Updated         28667
# Content Rating       28667
# Privacy Policy       23472
# Ad Supported         28667
# In App Purchases     28667
# Editors Choice       28667
# dtype: int64

# %% [markdown]
# ## 7. Dropping the missing or null values.

# %%
print(df.isnull().sum())
# Out:
# Name                    0
# ID                      0
# Category                1
# Rating                267
# Rating Count          267
# Installs                2
# Minimum Installs        2
# Maximum Installs        1
# Free                    1
# Price                   1
# Currency                2
# Size                    1
# Minimum Android        87
# Developer Id            1
# Developer Website    9461
# Developer Email         1
# Released              823
# Last Updated            1
# Content Rating          1
# Privacy Policy       5196
# Ad Supported            1
# In App Purchases        1
# Editors Choice          1
# dtype: int64

# %%
df = df.dropna()    # Dropping the missing values.
df.count()
# Out:
# Name                 15943
# ID                   15943
# Category             15943
# Rating               15943
# Rating Count         15943
# Installs             15943
# Minimum Installs     15943
# Maximum Installs     15943
# Free                 15943
# Price                15943
# Currency             15943
# Size                 15943
# Minimum Android      15943
# Developer Id         15943
# Developer Website    15943
# Developer Email      15943
# Released             15943
# Last Updated         15943
# Content Rating       15943
# Privacy Policy       15943
# Ad Supported         15943
# In App Purchases     15943
# Editors Choice       15943
# dtype: int64

# %%
print(df.isnull().sum())   # After dropping the values
# Out:
# Name                 0
# ID                   0
# Category             0
# Rating               0
# Rating Count         0
# Installs             0
# Minimum Installs     0
# Maximum Installs     0
# Free                 0
# Price                0
# Currency             0
# Size                 0
# Minimum Android      0
# Developer Id         0
# Developer Website    0
# Developer Email      0
# Released             0
# Last Updated         0
# Content Rating       0
# Privacy Policy       0
# Ad Supported         0
# In App Purchases     0
# Editors Choice       0
# dtype: int64

# %% [markdown]
# ## 8. Detecting Outliers

# %% [markdown]
# An outlier is a point or set of points that are different from other points. Sometimes they can be very high or very low. It's often a good idea to detect and remove the outliers. Because outliers are one of the primary reasons for resulting in a less accurate model. Hence it's a good idea to remove them. The outlier detection and removing that I am going to perform is called IQR score technique. Often outliers can be seen with visualizations using a box plot.

# %%
sns.boxplot(x=df['Rating Count'])
# Out:
# <Axes: xlabel='Rating Count'>

# %%
sns.boxplot(x=df['Price'])
# Out:
# <Axes: xlabel='Price'>

# %% [markdown]
# ## 9. Plot different features against one another

# %% [markdown]
# ##Histogram

# %%
df.Installs.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title("Ratings by Installs")
plt.ylabel('Ratings')
plt.xlabel('Installs');

# %% [markdown]
# ## Scatterplot

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=df['Maximum Installs'], y=df['Rating Count'])
# Out:
# <Axes: xlabel='Maximum Installs', ylabel='Rating Count'>

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x=df['Maximum Installs'],y=df['Rating Count'])
# Out:
# <Axes: xlabel='Maximum Installs', ylabel='Rating Count'>

# %% [markdown]
# ##Heatplot

# %%
plt.figure(figsize=(10,5))
c= df.corr()
sns.heatmap(c,annot=True)
# Out:
# <ipython-input-34-845a837895fd>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   c= df.corr()
# <Axes: >
